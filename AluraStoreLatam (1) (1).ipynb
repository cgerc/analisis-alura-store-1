# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto  ...       lat       lon
# 0  Asistente virtual           Electrónicos  ...   4.60971 -74.08175
# 1    Mesa de comedor                Muebles  ...   6.25184 -75.56359
# 2      Juego de mesa               Juguetes  ...  10.39972 -75.51444
# 3         Microondas      Electrodomésticos  ...   3.43722 -76.52250
# 4   Silla de oficina                Muebles  ...   6.25184 -75.56359
#
# [5 rows x 12 columns]

# %%
tienda4["id_tienda"] = 4
tienda3["id_tienda"] = 3
tienda2["id_tienda"] = 2
tienda["id_tienda"] = 1

# %%
tienda_total = pd.concat([tienda, tienda2, tienda3, tienda4])

# %%
tienda_total.count()
# Out:
# Producto                  9435
# Categoría del Producto    9435
# Precio                    9435
# Costo de envío            9435
# Fecha de Compra           9435
# Vendedor                  9435
# Lugar de Compra           9435
# Calificación              9435
# Método de pago            9435
# Cantidad de cuotas        9435
# lat                       9435
# lon                       9435
# id_tienda                 9435
# dtype: int64

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda_total.groupby("id_tienda")["Precio"].sum()
# Out:
# id_tienda
# 1    1.150880e+09
# 2    1.116344e+09
# 3    1.098020e+09
# 4    1.038376e+09
# Name: Precio, dtype: float64

# %%
tienda_total.groupby("id_tienda")["Precio"].mean()
# Out:
# id_tienda
# 1    487867.910131
# 2    473227.426876
# 3    465459.771089
# 4    440362.892282
# Name: Precio, dtype: float64

# %%
tienda_total.groupby("id_tienda")["Producto"].count()
# Out:
# id_tienda
# 1    2359
# 2    2359
# 3    2359
# 4    2358
# Name: Producto, dtype: int64

# %%
tienda_total.groupby(["id_tienda", "Método de pago"])["Precio"].sum()
# Out:
# id_tienda  Método de pago
# 1          Cupón                  64105500.0
#            Nequi                 232609700.0
#            Tarjeta de crédito    840665800.0
#            Tarjeta de débito      13499400.0
# 2          Cupón                  77366600.0
#            Nequi                 210748800.0
#            Tarjeta de crédito    816659500.0
#            Tarjeta de débito      11568600.0
# 3          Cupón                  47411300.0
#            Nequi                 229322400.0
#            Tarjeta de crédito    804570700.0
#            Tarjeta de débito      16715200.0
# 4          Cupón                  46986200.0
#            Nequi                 208003300.0
#            Tarjeta de crédito    768711100.0
#            Tarjeta de débito      14675100.0
# Name: Precio, dtype: float64

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda_total.groupby(["Categoría del Producto"])["Precio"].mean()
# Out:
# Categoría del Producto
# Artículos para el hogar    7.887644e+04
# Deportes y diversión       1.284615e+05
# Electrodomésticos          1.152960e+06
# Electrónicos               9.371199e+05
# Instrumentos musicales     4.631774e+05
# Juguetes                   5.705767e+04
# Libros                     5.080337e+04
# Muebles                    4.017291e+05
# Name: Precio, dtype: float64

# %%
tienda_total.groupby(["id_tienda", "Categoría del Producto"])["Precio"].sum()
# Out:
# id_tienda  Categoría del Producto
# 1          Artículos para el hogar     12698400.0
#            Deportes y diversión        39290000.0
#            Electrodomésticos          363685200.0
#            Electrónicos               429493500.0
#            Instrumentos musicales      91299000.0
#            Juguetes                    17995700.0
#            Libros                       8784900.0
#            Muebles                    187633700.0
# 2          Artículos para el hogar     14746900.0
#            Deportes y diversión        34744500.0
#            Electrodomésticos          348567800.0
#            Electrónicos               410831100.0
#            Instrumentos musicales     104990300.0
#            Juguetes                    15945400.0
#            Libros                      10091200.0
#            Muebles                    176426300.0
# 3          Artículos para el hogar     15060000.0
#            Deportes y diversión        35593100.0
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tienda_total.groupby(["id_tienda"])["Calificación"].mean()
# Out:
# id_tienda
# 1    3.976685
# 2    4.037304
# 3    4.048326
# 4    3.995759
# Name: Calificación, dtype: float64

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
tienda_total.groupby('id_tienda')['Producto'].apply(lambda x: x.mode()[0])
# Out:
# id_tienda
# 1                      Armario
# 2    Iniciando en programación
# 3                Kit de bancas
# 4                     Cama box
# Name: Producto, dtype: object

# %%
tienda_total.groupby('id_tienda')['Producto'].value_counts()
# Out:
# id_tienda  Producto
# 1          Armario                    60
#            Microondas                 60
#            TV LED UHD 4K              60
#            Secadora de ropa           58
#            Bloques de construcción    56
#                                       ..
# 4          Lavadora de ropa           38
#            Refrigerador               38
#            Guitarra acústica          37
#            Armario                    34
#            Guitarra eléctrica         33
# Name: Producto, Length: 204, dtype: int64

# %%
df_count_producto
# Out:
# id_tienda  Producto
# 1          Ajedrez de madera            49
#            Armario                      60
#            Asistente virtual            40
#            Auriculares                  50
#            Auriculares con micrófono    33
#                                         ..
# 4          Smartwatch                   39
#            Sofá reclinable              47
#            TV LED UHD 4K                40
#            Tablet ABXY                  45
#            Vaso térmico                 48
# Name: Precio, Length: 204, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <command-7268961889509876>, line 1
# ----> 1 df_count_producto.groupby(["id_tienda"])["Producto"].max()
#
# File /databricks/python/lib/python3.10/site-packages/pandas/core/base.py:248, in SelectionMixin.__getitem__(self, key)
#     246 else:
#     247     if key not in self.obj:
# --> 248         raise KeyError(f"Column not found: {key}")
#     249     subset = self.obj[key]
#     250     ndim = subset.ndim
#
# KeyError: 'Column not found: Producto'

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = tienda_total.groupby("id_tienda")["Costo de envío"].mean()

# %%
print(envio_promedio)
